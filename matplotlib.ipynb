# %% [markdown]
# <a href="https://colab.research.google.com/github/indranil046/4-febasian/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1:Matplotlib is a popular Python data visualization library used for
creating static, interactive, and animated plots and graphs.
It provides a variety of tools to help users visualize data in different formats.

Matplotlib is used for:

Understanding data patterns and trends

Communicating insights visually

Debugging and exploring datasets

Generating publication-quality graphs and plots


Line Plot – plt.plot()

Bar Chart – plt.bar()

Histogram – plt.hist()

Scatter Plot – plt.scatter()

Pie Chart – plt.pie()

2:A scatter plot is a type of plot used to display the relationship between two
variables. Each point on the scatter plot represents an observation with two
values — one plotted on the x-axis and the other on the y-axis.

import numpy as np
import matplotlib.pyplot as plt

# Generate data
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# Create scatter plot
plt.scatter(x, y, color='blue', marker='o')

# Add title and labels
plt.title('Scatter Plot of Randomly Generated Data')
plt.xlabel('X values')
plt.ylabel('Y values')

# Show the plot
plt.show()


3:The subplot() function in Matplotlib is used to create multiple plots in a
single figure (also called a multi-plot layout). It helps in comparing different
data visualizations side by side or in a grid format.

plt.subplot(nrows, ncols, index)
import numpy as np
import matplotlib.pyplot as plt

# Line 1 data
x = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])
# Line 2 data
y2 = np.array([50, 20, 40, 20, 60, 70])
# Line 3 data
y3 = np.array([10, 20, 30, 40, 50, 60])
# Line 4 data
y4 = np.array([200, 350, 250, 550, 450, 150])

# Create subplots
plt.figure(figsize=(10, 8))

# Plot 1
plt.subplot(2, 2, 1)
plt.plot(x, y1, color='red')
plt.title("Line 1")

# Plot 2
plt.subplot(2, 2, 2)
plt.plot(x, y2, color='blue')
plt.title("Line 2")

# Plot 3
plt.subplot(2, 2, 3)
plt.plot(x, y3, color='green')
plt.title("Line 3")

# Plot 4
plt.subplot(2, 2, 4)
plt.plot(x, y4, color='purple')
plt.title("Line 4")

# Adjust layout
plt.tight_layout()
plt.show()


4:A bar plot (or bar chart) is a type of chart that represents categorical data
with rectangular bars, where the length or height of each bar corresponds to the
value it represents.

import numpy as np
import matplotlib.pyplot as plt

# Data
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# Vertical Bar Plot
plt.figure(figsize=(8, 4))
plt.bar(company, profit, color='skyblue')
plt.title("Company Profit - Vertical Bar Plot")
plt.xlabel("Company")
plt.ylabel("Profit ($)")
plt.show()

# Horizontal Bar Plot
plt.figure(figsize=(8, 4))
plt.barh(company, profit, color='lightgreen')
plt.title("Company Profit - Horizontal Bar Plot")
plt.xlabel("Profit ($)")
plt.ylabel("Company")
plt.show()

5:A box plot (also called a box-and-whisker plot) is a statistical graph used to
 visualize the distribution, spread, and skewness of numerical data.

import numpy as np
import matplotlib.pyplot as plt

# Generate data
np.random.seed(5)
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# Combine data
data = [box1, box2]

# Plot
plt.figure(figsize=(6, 5))
plt.boxplot(data, labels=["Box 1", "Box 2"])
plt.title("Box Plot of Two Datasets")
plt.ylabel("Values")
plt.grid(True)
plt.show()
