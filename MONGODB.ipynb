# %% [markdown]
# <a href="https://colab.research.google.com/github/indranil046/4-febasian/blob/main/MONGODB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
###MONGODB ASSIENMENT
1:MongoDB is a powerful and flexible NoSQL database that caters to the needs of
modern applications requiring scalable, high-performance data management.
2:Document Model. MongoDB has been designed with developer productivity and
flexibility in mind. ...
Sharding. ...
Replication. ...
Authentication. ...
Database Triggers. ...
Time Series Data. ...
Ad-Hoc Queries. ...
Indexing.
3:pip install pymongo
from pymongo import MongoClient

# Connect to MongoDB (local server or remote MongoDB Atlas)
client = MongoClient("mongodb://localhost:27017/")  # For local MongoDB
# client = MongoClient("your_mongodb_atlas_connection_string")  # For MongoDB Atlas

# Create a database
db = client["my_database"]

# Create a collection
collection = db["my_collection"]

# Insert a sample document
sample_data = {"name": "Alice", "age": 25, "city": "New York"}
collection.insert_one(sample_data)

# Fetch and print the inserted document
result = collection.find_one({"name": "Alice"})
print(result)

# Close the connection
client.close()
4:from pymongo import MongoClient

# Connect to MongoDB (local or remote)
client = MongoClient("mongodb://localhost:27017/")  # Local MongoDB
# client = MongoClient("your_mongodb_atlas_connection_string")  # For MongoDB Atlas

# Select the database and collection
db = client["my_database"]   # Database created in Q3
collection = db["my_collection"]  # Collection created in Q3

# Insert one record
one_record = {"name": "Bob", "age": 30, "city": "Los Angeles"}
inserted_one = collection.insert_one(one_record)
print(f"Inserted One Record ID: {inserted_one.inserted_id}")

# Insert multiple records
many_records = [
    {"name": "Charlie", "age": 28, "city": "Chicago"},
    {"name": "David", "age": 35, "city": "San Francisco"},
    {"name": "Emma", "age": 27, "city": "Miami"}
]
inserted_many = collection.insert_many(many_records)
print(f"Inserted Many Record IDs: {inserted_many.inserted_ids}")

# Find and print one record
print("\nFind One Record:")
print(collection.find_one({"name": "Bob"}))  # Find a record with name "Bob"

# Find and print all records
print("\nFind All Records:")
for record in collection.find():
    print(record)

# Close the connection
client.close()
5:from pymongo import MongoClient

# Connect to MongoDB
client = MongoClient("mongodb://localhost:27017/")  # Replace with your MongoDB connection string
db = client["mydatabase"]  # Select the database
collection = db["users"]  # Select the collection

# Insert sample data (if collection is empty)
sample_data = [
    {"name": "Alice", "age": 25, "city": "New York"},
    {"name": "Bob", "age": 30, "city": "Los Angeles"},
    {"name": "Charlie", "age": 35, "city": "Chicago"}
]

if collection.count_documents({}) == 0:  # Insert only if the collection is empty
    collection.insert_many(sample_data)

# Query: Find all users older than 28
query = {"age": {"$gt": 28}}

# Execute the query
results = collection.find(query)

# Print the results
for doc in results:
    print(doc)
6:from pymongo import MongoClient

# Connect to MongoDB
client = MongoClient("mongodb://localhost:27017/")  # Replace with your MongoDB connection string
db = client["mydatabase"]  # Select the database
collection = db["users"]  # Select the collection

# Insert sample data (if collection is empty)
sample_data = [
    {"name": "Alice", "age": 25, "city": "New York"},
    {"name": "Bob", "age": 30, "city": "Los Angeles"},
    {"name": "Charlie", "age": 35, "city": "Chicago"},
    {"name": "David", "age": 28, "city": "San Francisco"}
]

if collection.count_documents({}) == 0:  # Insert only if the collection is empty
    collection.insert_many(sample_data)

# Sorting by age in ascending order
print("Sorted by age (Ascending):")
for doc in collection.find().sort("age", 1):  # 1 for ascending order
    print(doc)

# Sorting by age in descending order
print("\nSorted by age (Descending):")
for doc in collection.find().sort("age", -1):  # -1 for descending order
    print(doc)
7:from pymongo import MongoClient

# Connect to MongoDB
client = MongoClient("mongodb://localhost:27017/")
db = client["mydatabase"]
collection = db["users"]

# Delete one document where name is "Alice"
collection.delete_one({"name": "Alice"})
print("One document deleted")
