# %% [markdown]
# <a href="https://colab.research.google.com/github/indranil046/4-febasian/blob/main/pandas_adv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1:read_csv()
#read csv file
import pandas as pd
df=pd.read_csv('data.csv')
print(df)
df.head()
#first 5 data show
df.tail()
#last 5 data show
# Get summary statistics
print(df.describe())
# Display DataFrame structure
df.info()
# Drop a column named 'Age'
df_dropped = df.drop('Age', axis=1)  # axis=1 means column
print(df_dropped.head())



2:import pandas as pd

def reindex_dataframe(df):
    # Create a new index starting from 1 with step of 2
    new_index = range(1, 2 * len(df) + 1, 2)
    # Set the new index
    df.index = new_index
    return df
# Sample DataFrame
df = pd.DataFrame({
    'A': [10, 20, 30],
    'B': [100, 200, 300],
    'C': ['X', 'Y', 'Z']
})

print("Original DataFrame:\n", df)

# Reindex the DataFrame
df_reindexed = reindex_dataframe(df)

print("\nReindexed DataFrame:\n", df_reindexed)


3:import pandas as pd

def sum_first_three_values(df):
    total = 0
    count = 0
    for value in df['Values']:
        if count < 3:
            total += value
            count += 1
        else:
            break
    print("Sum of first three values:", total)
# Sample DataFrame
df = pd.DataFrame({
    'Values': [5, 10, 15, 20, 25]
})

sum_first_three_values(df)


4:import pandas as pd

def add_word_count_column(df):
    # Create a new column 'Word_Count' with the number of words in each 'Text' row
    df['Word_Count'] = df['Text'].apply(lambda x: len(str(x).split()))
    return df
# Sample DataFrame
df = pd.DataFrame({
    'Text': [
        "Hello world",
        "This is a sample sentence",
        "Pandas is fun!",
        ""
    ]
})

df = add_word_count_column(df)
print(df)


5:import pandas as pd

df = pd.DataFrame({
    'A': [1, 2, 3],
    'B': [4, 5, 6]
})

print(df.shape)  # Output: (3, 2)
3 rows and 2 columns
print(df.size)  # Output: 6
Total number of elements: 3 * 2 = 6


6:pd.read_excel()


7:import pandas as pd

def extract_usernames(df):
    # Create 'Username' column by splitting email at '@' and taking the first part
    df['Username'] = df['Email'].apply(lambda x: str(x).split('@')[0])
    return df
df = pd.DataFrame({
    'Email': ['alice@example.com', 'bob@gmail.com', 'charlie@yahoo.com']
})

df = extract_usernames(df)
print(df)


8:import pandas as pd

def filter_rows(df):
    filtered_df = df[(df['A'] > 5) & (df['B'] < 10)]
    return filtered_df
df=pd.DataFrame({
  A B C
0 3 5 1
1 8 2 7
2 6 9 4
3 2 3 5
4 9 1 2
})
filtered_df=filter_rows(df)
