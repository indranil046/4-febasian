# %% [markdown]
# <a href="https://colab.research.google.com/github/indranil046/4-febasian/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
5+4
# Out:
# 9

# %%
import pandas as pd
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-21b74fc6-5763-4b73-bb11-9205fc1cb96b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-21b74fc6-5763-4b73-bb11-9205fc1cb96b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
file_contents = uploaded['winequality-white.csv'].decode('utf-8')

# %%
from io import StringIO
df = pd.read_csv("winequality-white.csv", sep=';')
print(df)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
df[df.duplicated()]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.2              0.23         0.32             8.5      0.058
# 5               8.1              0.28         0.40             6.9      0.050
# 7               7.0              0.27         0.36            20.7      0.045
# 8               6.3              0.30         0.34             1.6      0.049
# 20              6.2              0.66         0.48             1.2      0.029
# ...             ...               ...          ...             ...        ...
# 4828            6.4              0.23         0.35            10.3      0.042
# 4850            7.0              0.36         0.35             2.5      0.048
# 4851            6.4              0.33         0.44             8.9      0.055
# 4856            7.1              0.23         0.39            13.7      0.058
# 4880            6.6              0.34         0.40             8.1      0.046
#
# ...

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 6               6.2              0.32         0.16             7.0      0.045
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
df["quality"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='quality'>

# %%
sns.distplot(df["quality"])
# Out:
# <ipython-input-15-41f950265a46>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["quality"])
# <Axes: xlabel='quality', ylabel='Density'>

# %%
df.nunique()
# Out:
# fixed acidity            68
# volatile acidity        125
# citric acid              87
# residual sugar          310
# chlorides               160
# free sulfur dioxide     132
# total sulfur dioxide    251
# density                 890
# pH                      103
# sulphates                79
# alcohol                 103
# quality                   7
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3961 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         3961 non-null   float64
#  1   volatile acidity      3961 non-null   float64
#  2   citric acid           3961 non-null   float64
#  3   residual sugar        3961 non-null   float64
#  4   chlorides             3961 non-null   float64
#  5   free sulfur dioxide   3961 non-null   float64
#  6   total sulfur dioxide  3961 non-null   float64
#  7   density               3961 non-null   float64
#  8   pH                    3961 non-null   float64
#  9   sulphates             3961 non-null   float64
#  10  alcohol               3961 non-null   float64
#  11  quality               3961 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 402.3 KB

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-330f8285-c1fe-4c02-9f4e-59512c2baa85" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-330f8285-c1fe-4c02-9f4e-59512c2baa85">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from io import StringIO
df1 = pd.read_csv("stud.csv")
print(df1)
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
df1.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
catcol=[feature for feature in df1.columns if df1[feature].dtype=='O']
numcol=[feature for feature in df1.columns if df1[feature].dtype!="O"]

# %%
catcol,numcol
# Out:
# (['gender',
#   'race_ethnicity',
#   'parental_level_of_education',
#   'lunch',
#   'test_preparation_course'],
#  ['math_score', 'reading_score', 'writing_score'])

# %%
numcol
# Out:
# ['math_score', 'reading_score', 'writing_score']

# %%
df1["total_score"]=(df1['math_score']+df1['reading_score']+df1['writing_score'])

# %%
df1["avg"]=df1["total_score"]/3

# %%
df1.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score        avg
# 0          218  72.666667
# 1          247  82.333333
# 2          278  92.666667
# 3          148  49.333333
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
#  8   total_score                  1000 non-null   int64
#  9   avg                          1000 non-null   float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 78.2+ KB

# %%
1+2
# Out:
# 3

# %%
import pandas as pd
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-37134351-1a3f-4d62-9593-8a4f81e06b55" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-37134351-1a3f-4d62-9593-8a4f81e06b55">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("height-weight.csv")

# %%
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
import matplotlib.pyplot as plt
plt.scatter(x=df["Weight"],y=df["Height"])

# %%
x=df[["Weight"]]
y=df["Height"]
x.shape
y.shape
# Out:
# (23,)

# %%
y.shape
# Out:
# (23,)

# %%
x
# Out:
#     Weight
# 0       45
# 1       58
# 2       48
# 3       60
# 4       70
# 5       78
# 6       80
# 7       90
# 8       95
# 9       78
# 10      82
# 11      95
# 12     105
# 13     100
# 14      85
# 15      78
# 16      50
# 17      65
# 18      76
# 19      87
# 20      45
# 21      56
# 22      72

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)

# %%
x_train.shape, x_test.shape
# Out:
# ((18, 1), (5, 1))

# %%
x_train
# Out:
#     Weight
# 12     105
# 1       58
# 13     100
# 5       78
# 2       48
# 11      95
# 20      45
# 3       60
# 4       70
# 18      76
# 16      50
# 21      56
# 22      72
# 7       90
# 10      82
# 14      85
# 19      87
# 6       80

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train
# Out:
#     Weight
# 12     105
# 1       58
# 13     100
# 5       78
# 2       48
# 11      95
# 20      45
# 3       60
# 4       70
# 18      76
# 16      50
# 21      56
# 22      72
# 7       90
# 10      82
# 14      85
# 19      87
# 6       80

# %%
x_train=scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 1.73689094],
#        [-0.92026952],
#        [ 1.4542143 ],
#        [ 0.21043706],
#        [-1.48562281],
#        [ 1.17153765],
#        [-1.6552288 ],
#        [-0.80719886],
#        [-0.24184557],
#        [ 0.0973664 ],
#        [-1.37255215],
#        [-1.03334018],
#        [-0.12877492],
#        [ 0.88886101],
#        [ 0.43657837],
#        [ 0.60618436],
#        [ 0.71925502],
#        [ 0.32350772]])

# %%
plt.scatter(x_train,y_train)

# %%
x_train
# Out:
# array([[ 1.73689094],
#        [-0.92026952],
#        [ 1.4542143 ],
#        [ 0.21043706],
#        [-1.48562281],
#        [ 1.17153765],
#        [-1.6552288 ],
#        [-0.80719886],
#        [-0.24184557],
#        [ 0.0973664 ],
#        [-1.37255215],
#        [-1.03334018],
#        [-0.12877492],
#        [ 0.88886101],
#        [ 0.43657837],
#        [ 0.60618436],
#        [ 0.71925502],
#        [ 0.32350772]])

# %%
x_test=scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.score(x_train,y_train)
# Out:
# 0.8930630841011482

# %%
reg.intercept_
# Out:
# 157.5

# %%
reg.coef_
# Out:
# array([17.03440872])

# %%
y_pred=reg.predict(x_test)

# %%
y_test
# Out:
# 15    177
# 9     170
# 0     120
# 8     182
# 17    159
# Name: Height, dtype: int64

# %%
y_pred
# Out:
# array([161.08467086, 161.08467086, 129.3041561 , 177.45645118,
#        148.56507414])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score,accuracy_score

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 9.822657814519232

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 109.77592599051664

# %%
r2_score(y_test, y_pred)
# Out:
# 0.776986986042344

# %%
from sklearn.datasets import fetch_california_housing
house=fetch_california_housing()

# %%
data=pd.DataFrame(house.data,columns=house.feature_names)

# %%
data.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
data["price"]=house.target

# %%
data.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
x=data.iloc[:,:-1]
y=data["price"]

# %%
x
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
y
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: price, Length: 20640, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(x_train, y_train)

# %%
reg.coef_
# Out:
# array([ 8.46603472e-01,  1.20333548e-01, -2.98800785e-01,  3.47243173e-01,
#        -8.81413334e-05, -4.17242067e-02, -8.94420371e-01, -8.70401317e-01])

# %%
reg.intercept_
# Out:
# 2.0666362048018536

# %%
y_pred=reg.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score,accuracy_score
mean_absolute_error(y_test, y_pred)
# Out:
# 0.5295710106684453

# %%
r2_score(y_test, y_pred)
# Out:
# 0.5970494128783952

# %%
import pickle
with open('model.pkl', 'wb') as file:
    pickle.dump(reg, file)

# %%
# Load the model from the file
with open('model.pkl', 'rb') as file:
    loaded_model = pickle.load(file)

# %%
x_new=[[120,150,154,180,170]]

# %%
y_pred = loaded_model.predict(x_new)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-20e3a5f8ae11> in <cell line: 1>()
# ----> 1 y_pred = loaded_model.predict(x_new)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     352             Returns predicted values.
#     353         """
# --> 354         return self._decision_function(X)
#     355
#     356     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     335         check_is_fitted(self)
#     336
# --> 337         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     338         return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     339
#
# ...

# %%
# !git clone https://github.com/indranil046/logistic-.git
# Out:
# Cloning into 'logistic-'...
# ...

# %%
# !git status
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# %cd logistic-
# Out:
# /content/logistic-

# %%
# !ls -la
# Out:
# total 12
# drwxr-xr-x 3 root root 4096 Apr 14 13:48 .
# drwxr-xr-x 1 root root 4096 Apr 14 13:48 ..
# drwxr-xr-x 7 root root 4096 Apr 14 13:48 .git

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/logistic-/.git/

# %%
# !git config user.email
# !git config user.name

# %%
# !git config --global user.email "indranilsaha046@gmail.com"
# !git config --global user.name "indranil046"

# %%
# !git status
# Out:
# On branch main
#
# No commits yet
#
# nothing to commit (create/copy files and use "git add" to track)

# %%
# !git add .

# %%
# !git commit -m "Initial commit"
# Out:
# On branch main
#
# Initial commit
#
# nothing to commit (create/copy files and use "git add" to track)

# %%
# !git push origin main
# Out:
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/indranil046/logistic-.git'

# %%
# !git checkout -b main
# Out:
# Switched to a new branch 'main'

# %%
# !git remote -v
# Out:
# origin	https://github.com/indranil046/logistic-.git (fetch)
# origin	https://github.com/indranil046/logistic-.git (push)

# %%
# !git remote set-url origin https://github.com/indranil046/logistic-.git

# %%
# !git push -f origin main
# Out:
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/indranil046/logistic-.git'

# %%
# !git branch

# %%
# !git checkout -b main
# Out:
# Switched to a new branch 'main'

# %%
# !git push -u origin main
# Out:
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/indranil046/logistic-.git'

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/logistic-/.git/

# %%
# !git commit -m "first commit"
# Out:
# On branch main
#
# Initial commit
#
# nothing to commit (create/copy files and use "git add" to track)

# %%
# !git add .

# %%
# !git remote add origin https://github.com/indranil046/logistic-.git
# Out:
# error: remote origin already exists.

# %%
# !git remote rm origin

# %%
# !git remote add origin https://github.com/indranil046/logistic-.git

# %%
# !git push -u origin main
# Out:
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/indranil046/logistic-.git'

# %%
# !git checkout -b main
# Out:
# Switched to a new branch 'main'

# %%
# !git add .
# !git commit -m "first commit"
# Out:
# On branch main
#
# Initial commit
#
# nothing to commit (create/copy files and use "git add" to track)

# %%
# !git status
# Out:
# On branch main
#
# No commits yet
#
# nothing to commit (create/copy files and use "git add" to track)

# %%
# !git add -A

# %%
# !git commit -m "first commit"
# Out:
# On branch main
#
# Initial commit
#
# nothing to commit (create/copy files and use "git add" to track)

# %%
# !git remote add origin https://github.com/indranil046/logistic-.git
# !git branch -M main
# !git push -u origin main
# Out:
# error: remote origin already exists.
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/indranil046/logistic-.git'

# %%
# !git push -u origin main
# Out:
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/indranil046/logistic-.git'

# %%
# !git checkout -b main
# Out:
# Switched to a new branch 'main'

# %%
! git pull --rebase origin main
# Out:
# fatal: Updating an unborn branch with changes added to the index.

# %%
# !git push -u origin main
# Out:
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/indranil046/logistic-.git'

# %%
# !git push -u origin main
# Out:
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/indranil046/logistic-.git'

# %%
# !git remote add origin https://github.com/indranil046/logistic-.git
# Out:
# error: remote origin already exists.

# %%
# !git push -u origin main
# Out:
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/indranil046/logistic-.git'

# %%
# !git remote add origin https://github.com/indranil046/logistic-.git
# Out:
# error: remote origin already exists.

# %%
# !git branch -M main
# !git push -u origin main
# Out:
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/indranil046/logistic-.git'

# %%
# !git branch
# !git status
# Out:
# On branch main
#
# No commits yet
#
# nothing to commit (create/copy files and use "git add" to track)

# %%
# !git push origin main
# Out:
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/indranil046/logistic-.git'

# %%
# !git commit -m "Your commit message"
# Out:
# On branch main
#
# Initial commit
#
# nothing to commit (create/copy files and use "git add" to track)

# %%
# !git add
# Out:
# Nothing specified, nothing added.
# hint: Maybe you wanted to say 'git add .'?
# hint: Turn this message off by running
# hint: "git config advice.addEmptyPathspec false"

# %%
# !git remote add origin https://github.com/indranil046/logistic-.git
# Out:
# error: remote origin already exists.

# %%
# !git push origin main
# Out:
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/indranil046/logistic-.git'
